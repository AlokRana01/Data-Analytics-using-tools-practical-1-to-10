# %%
import pandas as pd

# -------------------- Load Dataset --------------------
df = pd.read_csv("Sales_Dataset_2025.csv")

# -------------------- Basic Overview --------------------
print("=== DATASET OVERVIEW ===")

rows, cols = df.shape
print(f"Total Rows: {rows}")
print(f"Total Columns: {cols}")

print("\nData Types:\n")
print(df.dtypes)


# -------------------- Data Organization --------------------
print("\n=== DATA ORGANIZATION ===")

if isinstance(df, pd.DataFrame):
    print("Dataset Type: Structured (Tabular format with rows and columns)")


# -------------------- File Format --------------------
print("\n=== DATA FORMAT ===")
print("File Type: CSV (Comma-Separated Values)")


# -------------------- Data Structure Analysis --------------------
print("\n=== DATA STRUCTURE ===")

num_cols = df.select_dtypes(include=["number"]).columns.tolist()
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

print("Numerical Features:")
print(num_cols)

print("\nCategorical Features:")
print(cat_cols)


# -------------------- Analytical Usage --------------------
print("\n=== ANALYTICAL USAGE ===")

analysis_types = [
    "Descriptive Analysis",
    "Trend Analysis",
    "Statistical Modeling",
    "Predictive Analytics"
]

for analysis in analysis_types:
    print(f"✔ {analysis}")
# Out:
# === DATASET OVERVIEW ===
# Total Rows: 24
# Total Columns: 5
#
# Data Types:
#
# Month                object
# Region               object
# Sales                 int64
# Advertising_Spend     int64
# Profit                int64
# dtype: object
#
# === DATA ORGANIZATION ===
# Dataset Type: Structured (Tabular format with rows and columns)
#
# === DATA FORMAT ===
# File Type: CSV (Comma-Separated Values)
#
# === DATA STRUCTURE ===
# Numerical Features:
# ['Sales', 'Advertising_Spend', 'Profit']
#
# Categorical Features:
# ['Month', 'Region']
#
# === ANALYTICAL USAGE ===
# ✔ Descriptive Analysis
# ✔ Trend Analysis
# ✔ Statistical Modeling
# ✔ Predictive Analytics
