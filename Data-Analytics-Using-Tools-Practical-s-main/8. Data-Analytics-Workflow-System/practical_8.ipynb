# %%
# -------------------- IMPORT LIBRARIES --------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML


# -------------------- LOAD DATASET --------------------

df = pd.read_csv("student_scores_dataset.csv")

print("=== DATA PREVIEW ===")
display(HTML(df.head().to_html(index=False)))


# -------------------- DATA INFORMATION --------------------

print("\n=== DATASET INFO ===")
df.info()

print("\n=== STATISTICAL SUMMARY ===")
print(df.describe())

print("\n=== MISSING VALUES ===")
print(df.isnull().sum())


# -------------------- DATA CLEANING --------------------

# Fill missing numeric values with mean
df.fillna(df.mean(numeric_only=True), inplace=True)


# -------------------- FEATURE ENGINEERING --------------------

# Calculate average score
df["Avg_Score"] = df[["Math_Score", "Science_Score", "English_Score"]].mean(axis=1)

print("\n=== DATA WITH AVERAGE SCORE ===")
display(HTML(df.head().to_html(index=False)))


# -------------------- DATA VISUALIZATION --------------------

plt.figure()
plt.hist(df["Avg_Score"], bins=10)
plt.title("Average Score Distribution")
plt.xlabel("Average Marks")
plt.ylabel("Number of Students")
plt.show()


# -------------------- TOP PERFORMERS --------------------

print("\n=== TOP STUDENTS ===")
top_students = df.sort_values(by="Avg_Score", ascending=False).head()
display(HTML(top_students.to_html(index=False)))


# -------------------- FINAL HTML TABLE DISPLAY --------------------

print("\n=== FINAL DATASET (HTML VIEW) ===")
final_html = df.to_html(index=False, justify="center")
display(HTML(final_html))
# Out:
# === DATA PREVIEW ===
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Student_ID</th>
#       <th>Name</th>
#       <th>Math_Score</th>
#       <th>Science_Score</th>
#       <th>English_Score</th>
#       <th>Attendance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Aarav</td>
#       <td>78</td>
#       <td>82</td>
#       <td>74</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Vivaan</td>
#       <td>65</td>
#       <td>70</td>
#       <td>68</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Aditya</td>
#       <td>88</td>
#       <td>91</td>
#       <td>84</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Vihaan</td>
#       <td>72</td>
#       <td>75</td>
#       <td>70</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Arjun</td>
#       <td>90</td>
#       <td>85</td>
# ...
