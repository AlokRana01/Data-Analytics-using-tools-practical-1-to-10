# %%
import pandas as pd
import matplotlib.pyplot as plt# 1. Load Tabular Data
# Use pd.read_csv("your_file.csv") for external files
df = pd.read_csv("scottish_hills.csv")
# 2. Structured Summarization
print("--- Dataset Snapshot ---")
print(df.head(10)) # First 10 rows for initial interpretation
print("\n--- Summary Statistics ---")
# Generates mean, median, min, max, and std deviation
print(df.describe())
# 3. Categorical Interpretation
# Example: Grouping by a category to see trends (e.g., Average height per Region)
if 'Region' in df.columns:
 print("\n--- Region-wise Summary ---")
 print(df.groupby('Region')['Height'].mean())
# 4. Visual Interpretation (Box Plot)
# Useful for seeing distributions and identifying outliers
df.boxplot(column='Height')
plt.title('Distribution of Heights')
plt.ylabel('Meters')
plt.show()
# Out:
# --- Dataset Snapshot ---
#               Hill  Height  Latitude  Longitude           Region
# 0        Lochnagar    1155   56.9602    -3.2393    Royal Deeside
# 1  Bidean nam Bian    1150   56.6433    -5.0278          Glencoe
# 2        Ben Alder    1148   56.8125    -4.4633  Inverness-shire
# 3       Geal-Charn    1132   56.7325    -4.5025       Drumochter
# 4          Ben Lui    1130   56.3975    -4.8114           Argyll
# 5       Ben Macdui    1309   57.0704    -3.6683       Cairngorms
# 6     Schiehallion    1083   56.6669    -4.0047       Perthshire
# 7       Ben Lomond     974   56.1903    -4.6331    Stirlingshire
# 8    Beinn a' Ghlo    1129   56.8147    -3.6933       Perthshire
# 9       Mount Keen     939   56.9692    -2.9733            Angus
#
# --- Summary Statistics ---
#            Height   Latitude  Longitude
# count    10.00000  10.000000  10.000000
# mean   1114.90000  56.725750  -4.101700
# std     102.27463   0.269406   0.692513
# min     939.00000  56.190300  -5.027800
# 25%    1094.50000  56.649200  -4.600450
# 50%    1131.00000  56.772500  -4.234000
# 75%    1149.50000  56.923825  -3.674550
# max    1309.00000  57.070400  -2.973300
#
# --- Region-wise Summary ---
# Region
# Angus               939.0
# Argyll             1130.0
# Cairngorms         1309.0
# Drumochter         1132.0
# Glencoe            1150.0
# Inverness-shire    1148.0
# Perthshire         1106.0
# Royal Deeside      1155.0
# Stirlingshire       974.0
# Name: Height, dtype: float64
